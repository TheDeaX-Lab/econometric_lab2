# %% [markdown]
# # Вывод для линейной регрессии
# Линейный коэффициент корреляции y от x: 0.9697207601439933 </br>
# Коэффициент ранговой корреляции Спирмена: 0.36195773081201343</br>
# Коэффициент детерминации: 0.9403583526542421</br>
# Автокореляция остатков: Отсутствует</br>
# Средняя ошибка аппроксимации 9.876% </br>
# #### Доверительный интервал коэфициентов </br>
# Имеем на уровне значимости a = 0.05 :</br>
# tкрит = 2.048407141795244</br>
# $b0 \in ( 5.80340712084826 ; 10.724024721832034 )$</br>
# $b1 \in ( 1.945974119726564 ; 2.3663918227986422 )$</br>
# Имеем на уровне значимости a = 0.01 :</br>
# tкрит = 2.763262455461066</br>
# $b0 \in ( 4.944805926093095 ; 11.582625916587197 )$</br>
# $b1 \in ( 1.8726152100478806 ; 2.4397507324773255 )$</br>
# #### Доверительный интервал прогнозного значения y</br>
# Параметры прогнозного значения y: xp=11.407, yp=32.85929507453266</br>
# При a=0.05, Доверительный интервал прогнозного значения $y \in (26.504142947082798, 39.21444720198252$<br>
# Длина доверительного интервала прогнозного значения y: 12.710304254899725</br>
# При a=0.01, Доверительный интервал прогнозного значения $y \in (24.28631516530664, 41.43227498375868)$</br>
# Длина доверительного интервала прогнозного значения y: 17.14595981845204</br>
# #### Полученное уравнение регрессии:</br>
# $ 2.1561829712626* x + 8.26371592134015 $ </br>

# %% [markdown]
# # Вывод для нелинейной регрессии с показательной спецификацией
# Линейный коэффициент корреляции y от x: 0.9697207601439933 </br>
# Коэффициент ранговой корреляции Спирмена: 0.2004449388209122</br>
# Коэффициент детерминации: 0.9194381786979178</br>
# Автокореляция остатков: Присутствует</br>
# Средняя ошибка аппроксимации 11.397% </br>
# #### Доверительный интервал коэфициентов </br>
# Имеем на уровне значимости a = 0.05 :</br>
# tкрит = 2.048407141795244</br>
# $b0 \in ( 9.369277343047338 ; 15.088136994402786 )$</br>
# $b1 \in ( -0.16475331337048252 ; 0.323866212425172 )$</br>
# Имеем на уровне значимости a = 0.01 :</br>
# tкрит = 2.763262455461066</br>
# $b0 \in ( 8.371390466345275 ; 16.08602387110485 )$</br>
# $b1 \in ( -0.2500127955429998 ; 0.4091256945976893 )$</br>
# #### Доверительный интервал прогнозного значения y</br>
# Параметры прогнозного значения y: xp=11.407, yp=30.304210220538934</br>
# При a=0.05, Доверительный интервал прогнозного значения $y \in (22.92122171847412, 37.68719872260375)$</br>
# Длина доверительного интервала прогнозного значения y:  14.765977004129635</br>
# При a=0.01, Доверительный интервал прогнозного значения $y \in (20.344698500141064, 40.263721940936804)$</br>
# Длина доверительного интервала прогнозного значения y:  19.91902344079574</br>
# #### Полученное уравнение регрессии:</br>
# $ 12.2287071687251 \cdot 1.08280668172965^{x} $ </br>

# %% [markdown]
# # Итоговый вывод по исследованию
# Коэффициент ранговой корреляции Спирмена лучше у нелинейной регрессии 0:1</br>
# Коэффициент детерминации лучше у линейной регрессии 1:1</br>
# Автокореляция отсутствует у линейной регрессии 2:1</br>
# Т.к. изначально линейный коэффициент корреляции указывал на линейную зависимость 3:1</br>
# По средней ошибке аппроксимации лучше линейная регрессия 4:1</br>
# По охвату доверительного интервала лучше нелинейная регрессия 4:2</br>
# 4 балла в сторону линейной регрессии и 2 балла в сторону нелинейной</br>
# С текущими данными лучше использовать линейную регрессию</br>
